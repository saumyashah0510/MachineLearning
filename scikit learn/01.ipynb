# %% [markdown]
# # Scikit Learn

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer,fetch_california_housing

# %% [markdown]
# ### Loading and Fetching data

# %%
X,y = load_breast_cancer(return_X_y=True)

# %%
df = load_breast_cancer(as_frame=True).frame
df2 = fetch_california_housing(as_frame=True).frame

# %%
df2
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# 0        -122.23        4.526
# 1        -122.22        3.585
# 2        -122.24        3.521
# 3        -122.25        3.413
# 4        -122.25        3.422
# ...          ...          ...
# 20635    -121.09        0.781
# 20636    -121.21        0.771
# 20637    -121.22        0.923
# 20638    -121.32        0.847
# 20639    -121.24        0.894
#
# [20640 rows x 9 columns]

# %%
df.hist(figsize=(14,8))
plt.tight_layout()

# %%
df2.hist(figsize=(14,8))
plt.tight_layout()

# %% [markdown]
# ---
# ### Creating random blobs

# %%
from sklearn.datasets import make_blobs

X,y = make_blobs(n_samples=5000,centers=5)
X
# Out:
# array([[-6.35681644, -9.63376105],
#        [ 7.88614334, -2.91163255],
#        [ 8.01299482, -5.34359694],
#        ...,
#        [ 7.99652304, -3.94440806],
#        [ 8.01672272, -3.34709133],
#        [ 4.46544927,  7.73258027]], shape=(5000, 2))

# %%
y
# Out:
# array([4, 2, 0, ..., 2, 2, 3], shape=(5000,))

# %%
plt.scatter(X[:,0],X[:,1],c=y)

# %% [markdown]
# ---
# ### Making moons

# %%
from sklearn.datasets import make_moons

X1,y1 = make_moons(noise = 0.05)
plt.scatter(X1[:,0],X1[:,1],c=y1)
